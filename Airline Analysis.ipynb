# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

# %%
flight = pd.read_csv("flight.csv")
print(flight.head())
# Out:
#    miles  passengers  delay inflight_meal inflight_entertainment  \
# 0    792         172      0            No                    Yes
# 1   3163         214      0            No                    Yes
# 2   1832         212      0            No                    Yes
# 3    925         213      0            No                    Yes
# 4    967         217      0           Yes                    Yes
#
#   inflight_wifi day_of_week redeye weekend  coach_price  firstclass_price  \
# 0           Yes      Sunday    Yes     Yes      338.820           1571.02
# 1           Yes      Sunday     No     Yes      472.655           1663.70
# 2            No      Friday     No     Yes      351.960           1429.86
# 3           Yes    Saturday     No     Yes      387.835           1558.76
# 4           Yes      Monday     No      No      374.735           1245.58
#
#    hours
# 0      1
# 1      6
# 2      3
# 3      2
# 4      2

# %%
# What are high and low values? What would ve considered average? Does $500 seem like a good price for a coach ticket
print(np.mean(flight.coach_price))
print(np.median(flight.coach_price))

sns.histplot(flight.coach_price)
plt.show()
plt.clf()
# Out:
# 376.58525308213905
# 380.56

# %%
#Visualize the coach ticket prices for flights that are 8 hours long. What are the high, low, and average prices for 8-hour-long flights? DOes a $500 ticket seem more reasonable than before?
print(np.mean(flight.coach_price[flight.hours == 8]))
print(np.median(flight.coach_price[flight.hours == 8]))
sns.histplot(flight.coach_price[flight.hours == 8])
plt.show()
plt.clf()
# Out:
# 431.834377372817
# 437.115

# %%
sns.histplot(flight.delay[flight.delay <=500])
plt.show()
plt.clf()

# %%
perc = 0.1
flight_sub = flight.sample(n = int(flight.shape[0]*perc))
sns.lmplot(x = "coach_price", y = "firstclass_price", data = flight_sub, line_kws={'color': 'black'}, lowess=True)
plt.show()
plt.clf()
# Out:
# C:\Users\lehie\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(flight, x = "coach_price", hue = flight.inflight_meal)
plt.show()
plt.clf()

# %%
sns.histplot(flight, x = "coach_price", hue = flight.inflight_entertainment)
plt.show()
plt.clf()

# %%
sns.histplot(flight, x = "coach_price", hue = flight.inflight_wifi)
plt.show()
plt.clf()

# %%
sns.lmplot(x = "hours", y = "passengers", data = flight_sub, x_jitter = 0.25, scatter_kws={"s":5, "alpha":0.2}, fit_reg = False)
plt.show()
plt.clf()
# Out:
# C:\Users\lehie\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x = 'coach_price', y = 'firstclass_price', hue = 'weekend', data = flight_sub, fit_reg = False)
plt.show()
plt.clf()
# Out:
# C:\Users\lehie\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x = "day_of_week", y = "coach_price", hue = "redeye", data = flight)
plt.show()
plt.clf()
